# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
url = 'creditcard.csv'
creditcard = pd.read_csv(url)
creditcard
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %% [markdown]
# <h3>Information about data set-</h3>
#     The datasets contains transactions may be  credit cards in September 2013, by europen cardholders. This dataset presents
#     transactions that occured in two days, where we have 492 frauds out of 284807. The dataset is highly unbalanced, the
#     positive class(frauds) accounts for 0.172% of all transactions.
#     It contains only numeric variables which are the result of a PCA transformation. Unfortunately, due to confidentiality
#     issues, we cannot provide the original features and more background information about the data. Features V1, V2, V3, ..V28
#     are the principal components obtained with PCA, the only features which have not been transformed with PCA are 'Time' and
#     'Amount'. Feature 'Time' contains the seconds elapsed between each transaction and the first transaction in the dataset.

# %%
creditcard.shape
# Out:
# (284807, 31)

# %%
creditcard.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
creditcard['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# #2D-Scatter Plot-

# %%
sns.set_style('whitegrid')
sns.FacetGrid(creditcard, hue = 'Class', size = 6).map(plt.scatter, 'Time', 'Amount').add_legend()
plt.show()
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style('whitegrid')
sns.FacetGrid(creditcard, hue = 'Class', size = 6).map(plt.scatter, 'Amount', 'Time').add_legend()
plt.show()

# %% [markdown]
# <h3>Observations-</h3>
#     1. From the above two plots it is clearly visible that there are frauds only on the transactions which have transaction
#         amount approximately less than 2500. Transactions which have transaction amount approximately above 2500 have no fraud.
#     2. As per with the time, the frauds in the transactions are evenly distributed throughout time.
#
# <h2>3D- ScatterPlot</h2>

# %%
FilteredData = creditcard[['Time', 'Amount', 'Class']]
FilteredData
# Out:
#             Time  Amount  Class
# 0            0.0  149.62      0
# 1            0.0    2.69      0
# 2            1.0  378.66      0
# 3            1.0  123.50      0
# 4            2.0   69.99      0
# ...          ...     ...    ...
# 284802  172786.0    0.77      0
# 284803  172787.0   24.79      0
# 284804  172788.0   67.88      0
# 284805  172788.0   10.00      0
# 284806  172792.0  217.00      0
#
# [284807 rows x 3 columns]

# %%
FilteredData.shape
# Out:
# (284807, 3)

# %%
FilteredData['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
plt.close()
sns.set_style('whitegrid')
sns.pairplot(FilteredData, hue = 'Class', size = 5)
plt.show()
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\axisgrid.py:2071: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
countLess = 0
countMore = 0
for i in range(284806):
    if(FilteredData.iloc[i]['Amount'] < 2500):
        countLess = countLess + 1
    else:
        countMore = countMore + 1
print(countLess)
print(countMore)
# Out:
# 284357
# 449

# %%
percentage = (countLess / 284807) * 100
percentage
# Out:
# 99.84199826549207

# %% [markdown]
# <h3>Observations:</h3>
#     Now it has been calculated that there are 284357 transactions which has a transaction amount less than 2500. Means 99.84%
#     of transactions have transaction amount less than 2500.

# %%
class0 = 0
class1 = 0
for i in range(284806):
    if(FilteredData.iloc[i]['Amount'] < 2500):
        if(FilteredData.iloc[i]['Class'] == 0):
            class0 = class0 + 1
        else:
            class1 = class1 + 1
print(class0)
print(class1)
# Out:
# 283865
# 492

# %%
FilteredData['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %% [markdown]
# <h3>Observations:</h3>
#     Now the total number of fraud transactions in whole data are 492. It has been calculated that the total number of fraud
#     fraud transactions in data where transaction amount is less than 2500 is also 492. Therefore, all 100% fraud transactions
#     have transaction amount less than 2500. and there is no fraud transaction where transaction amount is more than 2500.

# %% [markdown]
# <h2>Histogram, PDF and CDF</h2>

# %%
creditcard_genuine = FilteredData.loc[FilteredData['Class'] == 0]
creditcard_fraud = FilteredData.loc[FilteredData['Class'] == 1]
plt.plot(creditcard_genuine['Time'], np.zeros_like(creditcard_genuine['Time']), "o")
plt.plot(creditcard_fraud['Time'], np.zeros_like(creditcard_fraud['Time']), "o")
plt.show()
#x-axis- Time

# %% [markdown]
# <h3>Observations:</h3>
#     Fraud and genuine transactions are spread evenly thought time and there is no clear distinction.

# %%
plt.plot(creditcard_genuine['Amount'], np.zeros_like(creditcard_genuine['Amount']), "o")
plt.plot(creditcard_fraud['Amount'], np.zeros_like(creditcard_fraud['Amount']), "o")

# %% [markdown]
# <h3>Observations:</h3>
#     It can clearly be observed from this 1D scatter plot that the fraud transactions are there only on the transaction amount
#     less than 2500.

# %%
sns.FacetGrid(FilteredData, hue = 'Class', size = 10).map(sns.distplot, 'Time').add_legend()
plt.show()
# Out:
# C:\Users\Asus\anaconda3\lib\site-packages\seaborn\axisgrid.py:243: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# <h3>Observations:</h3>
#     there is a heavy overlap of genuine and fraud transactions throughout  the time  and there is no clear distinction.

# %%
sns.FacetGrid(FilteredData, hue = 'Class', height = 10).map(sns.distplot, 'Amount').add_legend()
plt.show()

# %% [markdown]
# <h3>Observations:</h3>
#         Most of the transaction have amount less than  2500 approximately  and all  of the fraud transactions have transaction
#         amount less than 2500.
# <h3>Hence this is the best histogram we have.</h3>

# %%
counts, bin_edges = np.histogram(FilteredData['Amount'], bins = 10, density = True)
pdf = counts / (sum(counts))
print("pdf = ", pdf)
print("\n")
print("counts = ", counts)
print("\n")
print("Bin edges = ", bin_edges)
# Out:
# pdf =  [9.98553406e-01 1.26401388e-03 1.26401388e-04 3.51114966e-05
#  7.02229931e-06 3.51114966e-06 0.00000000e+00 7.02229931e-06
#  0.00000000e+00 3.51114966e-06]
#
#
# counts =  [3.88675874e-04 4.92003427e-07 4.92003427e-08 1.36667619e-08
#  2.73335237e-09 1.36667619e-09 0.00000000e+00 2.73335237e-09
#  0.00000000e+00 1.36667619e-09]
#
#
# Bin edges =  [    0.     2569.116  5138.232  7707.348 10276.464 12845.58  15414.696
#  17983.812 20552.928 23122.044 25691.16 ]

# %% [markdown]
# <h3>Observations:</h3>
#     Probability of the points having transaction amount approximately less than 2500 is 1, it means almost all of the
#     transactions have transaction amount less than 2500 and cdf  curve verifies this fact.
#     <h1>Mean, Variance and Std-dev</h1>

# %%
print('Means:')
print('Mean of transaction amount of genuine transactions: ', np.mean(creditcard_genuine['Amount']))
print('Mean of transaction amount of fraud transactions: ', np.mean(creditcard_fraud['Amount']))
# Out:
# Means:
# Mean of transaction amount of genuine transactions:  88.29102242225574
# Mean of transaction amount of fraud transactions:  122.21132113821133

# %%
print('Standard Deviation:')
print('Std-Deviation of transaction amount of genuine transactions: ', np.std(creditcard_genuine['Amount']))
print('Std-Deviation of transaction amount of fraud transactions: ', np.std(creditcard_fraud['Amount']))
# Out:
# Standard Deviation:
# Std-Deviation of transaction amount of genuine transactions:  250.1046523874637
# Std-Deviation of transaction amount of fraud transactions:  256.42229861324483

# %%
print('Median:')
print('Median of transaction amount of genuine transactions: ', np.median(creditcard_genuine['Amount']))
print('Median of transaction amount of fraud transactions: ', np.median(creditcard_fraud['Amount']))
# Out:
# Median:
# Median of transaction amount of genuine transactions:  22.0
# Median of transaction amount of fraud transactions:  9.25

# %%
print('Quantiles:')
print(np.percentile(creditcard_genuine['Amount'], np.arange(0, 100, 25)))
print(np.percentile(creditcard_fraud['Amount'], np.arange(0, 100, 25)))
# Out:
# Quantiles:
# [ 0.    5.65 22.   77.05]
# [  0.     1.     9.25 105.89]

# %% [markdown]
# <h2>Box Plots and Whiskers</h2>

# %%
sns.boxplot(x = 'Class', y = 'Time', data = creditcard)
plt.show()

# %% [markdown]
# <h3>Observations:</h3>
#     By looking at the above box plot we can say that both fraud & genuine transactions occur throughout time and there is no
#     distinction between them.

# %%
sns.boxplot(x = 'Class', y = 'Amount', data = creditcard)
plt.ylim(0, 5000)
plt.show()

# %% [markdown]
# <h3>Observations:</h3>
#     From above box plot we can easily infer that there are no fraud transactions occur above the transaction amount of 3000.
#     All of the fraud transactions have transaction amount less than 3000. However, there are many transactions which have a
#     transaction amount greater than 3000 and all of them are genuine.
#     <h1>Similarity</h1>

# %%
from scipy import spatial

# %%
sampleData = creditcard.head(20000) #Sample the data from original data so as to save the computation time

# %%
samples = creditcard.loc[30401:30500] #taking samples of size 100 from index 30401 to 30500

# %%
# %%javascript
# IPython.OutputArea.prototype._should_scroll = function(lines) {
#     return false;
# }

# %%
frame = []

# %%
for i in range(30401, 30501):
    t1 = samples.loc[i]
    c = samples.loc[i]['Class']
    for j in range(20000):
        t2 = sampleData.loc[j]
        classLabel = creditcard.loc[j]['Class']
        similarity = 1 - spatial.distance.cosine(t1, t2)
        frame.append([classLabel, similarity, j])
    df = pd.DataFrame(frame, columns = ['Class', 'Similarity', 'Transaction ID'])
    df_sorted = df.sort_values('Similarity', ascending = False)
    print('Top 10 transactions having highest similarity with transaction ID = ' + str(i) + ' and class = ' + str(c) + ':')
    print(df_sorted.iloc[:10])
    print("\n")
    frame = []
# Out:
# Top 10 transactions having highest similarity with transaction ID = 30401 and class = 0.0:
#        Class  Similarity  Transaction ID
# 16709    0.0         1.0           16709
# 18754    0.0         1.0           18754
# 15840    0.0         1.0           15840
# 16254    0.0         1.0           16254
# 18586    0.0         1.0           18586
# 16628    0.0         1.0           16628
# 18438    0.0         1.0           18438
# 18046    0.0         1.0           18046
# 15946    0.0         1.0           15946
# 14804    0.0         1.0           14804
#
#
# Top 10 transactions having highest similarity with transaction ID = 30402 and class = 0.0:
#        Class  Similarity  Transaction ID
# 19040    0.0         1.0           19040
# 16720    0.0         1.0           16720
# 18994    0.0         1.0           18994
# 19142    0.0         1.0           19142
# 15480    0.0         1.0           15480
# 17628    0.0         1.0           17628
# ...
